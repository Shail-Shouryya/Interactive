# %%
import pandas as pd

# %%
df = pd.read_csv('Weather_of_500_Cities.csv')#,index_col = 'City')

# %%
df
# Out:
#                  Unnamed: 0  Cloudiness Country        Date  Humidity    Lat  \
# City
# Lincoln                   0           1      us  1535686500        95  40.80
# Torbay                    1          90      ca  1535684400       100  47.66
# Punta Arenas              2          20      cl  1535688000        86 -53.16
# Shingu                    3          75      jp  1535684400        83  33.72
# Bossangoa                 4          80      cf  1535689111        96   6.50
# Provideniya               5          75      ru  1535686200        76  64.42
# Rikitea                   6          20      pf  1535688908       100 -23.12
# Vaini                     7          88      in  1535689111        99  15.34
# Ushtobe                   8           0      kz  1535689111        77  45.25
# Vila Velha                9          75      br  1535688000        74  -3.71
# Kavieng                  10          64      pg  1535689112       100  -2.57
# ...

# %%
df = df.drop(axis=1, columns=["Unnamed: 0"])

# %%
df
# Out:
#                  Cloudiness Country        Date  Humidity    Lat     Lng  \
# City
# Lincoln                   1      us  1535686500        95  40.80  -96.67
# Torbay                   90      ca  1535684400       100  47.66  -52.73
# Punta Arenas             20      cl  1535688000        86 -53.16  -70.91
# Shingu                   75      jp  1535684400        83  33.72  135.99
# Bossangoa                80      cf  1535689111        96   6.50   17.45
# Provideniya              75      ru  1535686200        76  64.42 -173.23
# Rikitea                  20      pf  1535688908       100 -23.12 -134.97
# Vaini                    88      in  1535689111        99  15.34   74.49
# Ushtobe                   0      kz  1535689111        77  45.25   77.98
# Vila Velha               75      br  1535688000        74  -3.71  -38.60
# Kavieng                  64      pg  1535689112       100  -2.57  150.80
# Kahului                  40      us  1535687760        74  20.89 -156.47
# ...

# %%
df.to_html('citiesWeather_df.html')
